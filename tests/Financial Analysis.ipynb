# %% [markdown]
# # Financial Analysis in Python

# %% [markdown]
# What you will learn in this tutorial
# ------------------------------------
#
# * Timeseries analysis using Pandas
# * Using Google Trends to predict market movements
# * Build your own trading strategy using Zipline
# * Common trading strategies:
#    * Momentum trading
#    * Mean-reversion

# %% [markdown]
# Different stages towards a successful trading strategy
# ------------------------------------------------------
#
# 1. Data analysis / Idea generation
#    * Pandas + Matplotlib (Part I)
# 2. Backtest strategy
#    * Pandas can be used but many limitations (Part II)
#    * -> Zipline (Part III)
# 3. Optimize
#    * See my previous [PyData talk](http://blog.quantopian.com/zipline_in_the_cloud/)
# 4. Forward test strategy (paper trading)
#    * Trivial on Quantopian (Part IV)
# 5. Live trading!
#    * Coming soon...

# %% [markdown]
# This notebook was adapted from [Thomas Wiecki's tutorial on financial analysis.](https://github.com/twiecki/financial-analysis-python-tutorial)

# %% [markdown]
# ##Make these edits:
#
# * Create one additional chart in the notebook.
# * Create a cell that shows the standard deviation in price of IBM.
# * Create a cell that shows the average volume for AAPL
# * Right before the 'Pandas basics ...' heading, create two new cells. The first is a Level 1 heading, titled 'Local Changes'.
# * Below the heading, add a Markdown cell that:
#     1. Lists your name
#     2. Describes any other changes you made to the notebook
#     3. States the standard deviation and average values that you found.
# * Commit these changes to git, and push the changes to Github. Verify that you have the file 'aapl_ohlc.csv' in the 'tests' of your repository on github.com
# * Create an entry for your repository at http://nbviewer.ipython.org/
# * Send a link to the NBViewer page created in 6 to : eric@sandiegodata.org and interns@sandiegodata.org.

# %% [markdown]
# #Local Changes

# %% [markdown]
# Gonzalo Urrutia <br>
# Changes: Created a plot for the adjusted closing price of NASDAQ composite index from 2006 to 2014<br>
# Standard Deviation of IBM = 28.586620016589336<br>
# Average Volume of AAPL = 188289640.74074075

# %%
nasdaq = pd.io.data.get_data_yahoo('^IXIC', 
                                 start=datetime.datetime(2006, 1, 1), 
                                 end=datetime.datetime(2014, 1, 1))['Adj Close']
nasdaq.head()
# Out:
# Date
# 2006-01-03    2243.74
# 2006-01-04    2263.46
# 2006-01-05    2276.87
# 2006-01-06    2305.62
# 2006-01-09    2318.69
# Name: Adj Close, dtype: float64

# %%
nasdaq.plot(label='^IXIC')
plt.legend()

# %%
df['IBM'].std()
# Out:
# 28.586620016589336

# %%
aapl.Volume.mean()
# Out:
# 188289640.74074075

# %% [markdown]
# # Pandas basics (Data analysis / Idea generation)

# %%
# %matplotlib inline
import numpy as np

# %%
from IPython.core.display import HTML
HTML("<iframe src=http://pandas.pydata.org width=800 height=350></iframe>")
# Out:
# <iframe src=http://pandas.pydata.org width=800 height=350></iframe>

# %%
import datetime

import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame
pd.__version__
# Out:
# '0.13.1'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__
# Out:
# '1.1.1'

# %% [markdown]
# Creating/loading time series data
# ===================
#
# * From Python structures
# * From Yahoo finance
# * From CSV files

# %% [markdown]
# ### From Python structures

# %%
labels = ['a', 'b', 'c', 'd', 'e']
s = Series([1, 2, 3, 4, 5], index=labels)
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
'b' in s
# Out:
# True

# %%
s['b']
# Out:
# 2

# %%
mapping = s.to_dict()
mapping
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
Series(mapping)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# ### From Yahoo finance

# %%
aapl = pd.io.data.get_data_yahoo('AAPL', 
                                 start=datetime.datetime(2006, 10, 1), 
                                 end=datetime.datetime(2012, 1, 1))
aapl.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2006-10-02  75.10  75.87  74.30  74.86  178159800      10.22
# 2006-10-03  74.45  74.95  73.19  74.08  197677200      10.12
# 2006-10-04  74.10  75.46  73.16  75.38  207270700      10.29
# 2006-10-05  74.53  76.16  74.13  74.83  170970800      10.22
# 2006-10-06  74.42  75.04  73.81  74.22  116739700      10.13
#
# [5 rows x 6 columns]

# %%
aapl.Volume.mean()
# Out:
# 188289640.74074075

# %% [markdown]
# ### From CSV files

# %%
aapl.to_csv('aapl_ohlc.csv')
# !head aapl_ohlc.csv
# Out:
# Date,Open,High,Low,Close,Volume,Adj Close
# 2006-10-02,75.1,75.87,74.3,74.86,178159800,10.22
# 2006-10-03,74.45,74.95,73.19,74.08,197677200,10.12
# 2006-10-04,74.1,75.46,73.16,75.38,207270700,10.29
# 2006-10-05,74.53,76.16,74.13,74.83,170970800,10.22
# 2006-10-06,74.42,75.04,73.81,74.22,116739700,10.13
# 2006-10-09,73.8,75.08,73.53,74.63,109555600,10.19
# 2006-10-10,74.54,74.58,73.08,73.81,132897100,10.08
# 2006-10-11,73.42,73.98,72.6,73.23,142963800,10.0
# 2006-10-12,73.61,75.39,73.6,75.26,148213800,10.28

# %%
df = pd.read_csv('aapl_ohlc.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2006-10-02  75.10  75.87  74.30  74.86  178159800      10.22
# 2006-10-03  74.45  74.95  73.19  74.08  197677200      10.12
# 2006-10-04  74.10  75.46  73.16  75.38  207270700      10.29
# 2006-10-05  74.53  76.16  74.13  74.83  170970800      10.22
# 2006-10-06  74.42  75.04  73.81  74.22  116739700      10.13
#
# [5 rows x 6 columns]

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2006-10-02, ..., 2011-12-30]
# Length: 1323, Freq: None, Timezone: None

# %% [markdown]
# Series and DataFrame: First steps
# =================================
#
# * Indexing
# * Slicing
# * Creating new columns

# %%
ts = df['Close'][-10:]
ts
# Out:
# Date
# 2011-12-16    381.02
# 2011-12-19    382.21
# 2011-12-20    395.95
# 2011-12-21    396.45
# 2011-12-22    398.55
# 2011-12-23    403.33
# 2011-12-27    406.53
# 2011-12-28    402.64
# 2011-12-29    405.12
# 2011-12-30    405.00
# Name: Close, dtype: float64

# %% [markdown]
# A DataFrame is a collection of Series objects. Slicing out a DataFrame column returns a Series.

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
date = ts.index[5]
date
# Out:
# Timestamp('2011-12-23 00:00:00', tz=None)

# %%
ts[date]
# Out:
# 403.32999999999998

# %%
ts[5]
# Out:
# 403.32999999999998

# %% [markdown]
# We can also select multiple columns.

# %%
df[['Open', 'Close']].head()
# Out:
#              Open  Close
# Date
# 2006-10-02  75.10  74.86
# 2006-10-03  74.45  74.08
# 2006-10-04  74.10  75.38
# 2006-10-05  74.53  74.83
# 2006-10-06  74.42  74.22
#
# [5 rows x 2 columns]

# %% [markdown]
# New columns can be added on the fly.

# %%
df['diff'] = df.Open - df.Close
df.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close  diff
# Date
# 2006-10-02  75.10  75.87  74.30  74.86  178159800      10.22  0.24
# 2006-10-03  74.45  74.95  73.19  74.08  197677200      10.12  0.37
# 2006-10-04  74.10  75.46  73.16  75.38  207270700      10.29 -1.28
# 2006-10-05  74.53  76.16  74.13  74.83  170970800      10.22 -0.30
# 2006-10-06  74.42  75.04  73.81  74.22  116739700      10.13  0.20
#
# [5 rows x 7 columns]

# %% [markdown]
# ...and deleted on the fly.

# %%
del df['diff']
df.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2006-10-02  75.10  75.87  74.30  74.86  25451400      71.55
# 2006-10-03  74.45  74.95  73.19  74.08  28239600      70.81
# 2006-10-04  74.10  75.46  73.16  75.38  29610100      72.05
# 2006-10-05  74.53  76.16  74.13  74.83  24424400      71.52
# 2006-10-06  74.42  75.04  73.81  74.22  16677100      70.94
#
# [5 rows x 6 columns]

# %% [markdown]
# Common Financial Computations
# -----------------------------
#
# * Moving Average
# * Returns

# %%
aapl.Volume.mean()
# Out:
# 188289640.74074075

# %%
close_px = df['Adj Close']

# %%
mavg = pd.rolling_mean(close_px, 40)
mavg[-10:]
# Out:
# Date
# 2011-12-16    53.07575
# 2011-12-19    53.03950
# 2011-12-20    53.00600
# 2011-12-21    53.00150
# 2011-12-22    52.99450
# 2011-12-23    52.98975
# 2011-12-27    52.99525
# 2011-12-28    52.98800
# 2011-12-29    53.01750
# 2011-12-30    53.04350
# dtype: float64

# %% [markdown]
# Returns defined as:
# $$ $$
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
rets = close_px / close_px.shift(1) - 1
rets.head()
# Out:
# Date
# 2006-10-02         NaN
# 2006-10-03   -0.010342
# 2006-10-04    0.017512
# 2006-10-05   -0.007356
# 2006-10-06   -0.008110
# Name: Adj Close, dtype: float64

# %% [markdown]
# Or alternatively `.pct_change()`.

# %%
close_px.pct_change().head()
# Out:
# Date
# 2006-10-02         NaN
# 2006-10-03   -0.010342
# 2006-10-04    0.017512
# 2006-10-05   -0.007356
# 2006-10-06   -0.008110
# Name: Adj Close, dtype: float64

# %% [markdown]
# Plotting Basics
# ---------------

# %% [markdown]
# Series and DataFrames have an associated `.plot()` command (uses Matplotlib behind the scenes).

# %%
close_px.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()

# %% [markdown]
# ## Optional: If there is time...

# %%
df = pd.io.data.get_data_yahoo(['AAPL', 'GE', 'IBM', 'KO', 'MSFT', 'PEP'], 
                               start=datetime.datetime(2010, 1, 1), 
                               end=datetime.datetime(2013, 1, 1))['Adj Close']
df.head()
# Out:
#              AAPL     GE     IBM     KO   MSFT    PEP
# Date
# 2010-01-04  29.22  13.44  121.91  25.02  27.48  53.54
# 2010-01-05  29.27  13.51  120.44  24.72  27.49  54.19
# 2010-01-06  28.81  13.44  119.66  24.71  27.32  53.64
# 2010-01-07  28.75  14.14  119.24  24.65  27.03  53.30
# 2010-01-08  28.94  14.44  120.44  24.19  27.22  53.13
#
# [5 rows x 6 columns]

# %%
df['AAPL'].std()
# Out:
# 19.146035424406222

# %%
rets = df.pct_change()

# %%
plt.scatter(rets.PEP, rets.KO)
plt.xlabel('Returns PEP')
plt.ylabel('Returns KO')

# %%
pd.scatter_matrix(rets, diagonal='kde', figsize=(10, 10));

# %%
corr = rets.corr()
corr
# Out:
#           AAPL        GE       IBM        KO      MSFT       PEP
# AAPL  1.000000  0.456812  0.501597  0.387162  0.472838  0.309169
# GE    0.456812  1.000000  0.609314  0.593249  0.599459  0.533473
# IBM   0.501597  0.609314  1.000000  0.600913  0.645910  0.491271
# KO    0.387162  0.593249  0.600913  1.000000  0.522307  0.635050
# MSFT  0.472838  0.599459  0.645910  0.522307  1.000000  0.476821
# PEP   0.309169  0.533473  0.491271  0.635050  0.476821  1.000000
#
# [6 rows x 6 columns]

# %%
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns)
plt.yticks(range(len(corr)), corr.columns);

# %% [markdown]
# One thing we are often interested in is the relationship of expected returns and the risk we are taking one. Often there is a trade-off between the two.
#
# Here we use `plt.annotate` to put labels on the scatterplot.

# %%
plt.scatter(rets.mean(), rets.std())
plt.xlabel('Expected returns')
plt.ylabel('Risk')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %% [markdown]
# Data alignment and dealing with missing values
# ==============
#
# * Join, merge, concatenate
# * Filling NaNs

# %% [markdown]
# Lets pull some more securities from Yahoo finance and build a DataFrame of the adjusted closing prices.

# %%
series_list = []
securities = ['AAPL', 'IBM', 'MSFT', 'PEP']
for security in securities:
    s = pd.io.data.get_data_yahoo(security, start=datetime.datetime(2011, 10, 1), end=datetime.datetime(2013, 1, 1))['Adj Close']
    s.name = security # Rename series to match security name
    series_list.append(s)

# %% [markdown]
# `pd.concat` can be used to concatenate multiple `Series` into one `DataFrame`.

# %%
df = pd.concat(series_list, axis=1)
df.head()
# Out:
#               AAPL     IBM   MSFT    PEP
# Date
# 2011-10-03  358.05  164.64  22.65  55.97
# 2011-10-04  356.04  166.02  23.40  56.12
# 2011-10-05  361.54  168.02  23.91  55.97
# 2011-10-06  360.70  172.62  24.32  56.23
# 2011-10-07  353.46  173.29  24.24  56.65
#
# [5 rows x 4 columns]

# %%
df.ix[0, 'AAPL'] = np.nan
df.ix[1, ['PEP', 'IBM']] = np.nan
df.ix[[1, 2, 3], 'MSFT'] = np.nan

df.head()
# Out:
#               AAPL     IBM   MSFT    PEP
# Date
# 2011-10-03     NaN  164.64  22.65  55.97
# 2011-10-04  356.04     NaN    NaN    NaN
# 2011-10-05  361.54  168.02    NaN  55.97
# 2011-10-06  360.70  172.62    NaN  56.23
# 2011-10-07  353.46  173.29  24.24  56.65
#
# [5 rows x 4 columns]

# %% [markdown]
# Pandas has great support for computing with missing values.

# %%
(df.AAPL + df.PEP).head()
# Out:
# Date
# 2011-10-03       NaN
# 2011-10-04       NaN
# 2011-10-05    417.51
# 2011-10-06    416.93
# 2011-10-07    410.11
# dtype: float64

# %% [markdown]
# One common approacht to impute missing values in time series is forward filling.

# %%
df.ffill().head()
# Out:
#               AAPL     IBM   MSFT    PEP
# Date
# 2011-10-03     NaN  164.64  22.65  55.97
# 2011-10-04  356.04  164.64  22.65  55.97
# 2011-10-05  361.54  168.02  22.65  55.97
# 2011-10-06  360.70  172.62  22.65  56.23
# 2011-10-07  353.46  173.29  24.24  56.65
#
# [5 rows x 4 columns]

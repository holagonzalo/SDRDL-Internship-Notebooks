# %%
import pandas as pd
pd.options.display.max_columns = 20

df = pd.read_csv('https://s3.amazonaws.com/ds.civicknowledge.org/211sandiego.org/service_calls_211_2013_14_sample.csv')

# %%
df.head()
# Out:
#    id call_stat   restrictions                     create_time  client_id    queue                call_type relationship called_before       how_hear have_ins  ins_type hshld_disabled  gender age_goups  caller_age  preg_lt6  child_lt6 ethnicity race language hshld_size income_source  hshld_income hshld_pct_fpl  income_declined    zip     need_tax_code                         need_tax_cat need_unmet                      need_reason_unmet                    ref_agency                                           ref_name
# ...
